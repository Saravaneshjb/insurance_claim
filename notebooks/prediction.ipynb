# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('test_Inceptez20.csv')

# %%
df.head()
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID50001       1.078602        0.14             0.346154           C8
# 1   ID50002       0.176011        0.15             0.471154          C21
# 2   ID50003       0.088625        0.09             0.384615           C3
# 3   ID50004       1.174575        0.13             0.326923           C3
# 4   ID50005       1.102165        0.15             0.509615           C2
#
#    population_density  make segment model fuel_type  ...  \
# 0                8794     3      C2    M4    Diesel  ...
# 1                3264     1      B2    M6    Petrol  ...
# 2                4076     3      C2    M4    Diesel  ...
# 3                4076     2       A    M3    Petrol  ...
# 4               27003     1      B1    M8       CNG  ...
#
#   is_rear_window_defogger is_brake_assist is_power_door_locks  \
# 0                     Yes             Yes                 Yes
# ...

# %%
df.shape
# Out:
# (8592, 43)

# %%
df.isna().sum()
# Out:
# policy_id                           0
# policy_tenure                       0
# age_of_car                          0
# age_of_policyholder                 0
# area_cluster                        0
# population_density                  0
# make                                0
# segment                             0
# model                               0
# fuel_type                           0
# max_torque                          0
# max_power                           0
# engine_type                         0
# airbags                             0
# is_esc                              0
# is_adjustable_steering              0
# is_tpms                             0
# is_parking_sensors                  0
# is_parking_camera                   0
# rear_brakes_type                    0
# displacement                        0
# cylinder                            0
# transmission_type                   0
# gear_box                            0
# steering_type                       0
# ...
